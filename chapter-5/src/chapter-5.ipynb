# %%
# 下記セルを実行すると、authorization codeの入力を求められます。
# 出力されたリンク先をクリックし、Googleアカウントにログインし、
# authorization codeをコピーし、貼り付けをおこなってください。
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#import os 
#project = '100knock-process-visualization'
#chapter = 5
#os.chdir(f'/content/drive/MyDrive/{project}/chapter-{chapter}/')

# %% [markdown]
# # ５章 画像データの加工・可視化を行う１０本ノック

# %% [markdown]
# ## ノック６１：画像ファイルを読み込んで表示してみよう

# %%
from PIL import Image
import cv2 
from IPython.display import display

img = cv2.imread("../data/sample.jpg")
img

# %%
#cv2.imshow("sample.jpg", img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
display(Image.fromarray(img))

# %% [markdown]
# ## ノック６２：画像データの中身を確認しよう

# %%
img.shape

# %%
print(img[0])
print(img[0].shape)

# %%
print(img[:,0])
print(img[:,0].shape)

# %%
print(img[:,:,0])
print(img[:,:,0].shape)

# %% [markdown]
# ## ノック６３：画像データを切り出してみよう

# %%
img_extract = img[700:1200,300:800,:]
#cv2.imshow("sample.jpg", img_extract)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
display(Image.fromarray(img_extract))

# %%
#cv2.imshow("sample.jpg", img_extract[:,:,0])
#cv2.waitKey(0)
#cv2.destroyAllWindows()
display(Image.fromarray(img_extract[:,:,0]))

# %%
#cv2.imshow("sample.jpg", img_extract[:,:,1])
#cv2.waitKey(0)
#cv2.destroyAllWindows()
display(Image.fromarray(img_extract[:,:,1]))

# %% [markdown]
# ## ノック６４：カラーヒストグラムを可視化してみよう

# %%
hist_b = cv2.calcHist([img], channels=[0], mask=None, histSize=[256], ranges=[0,256])
print(hist_b.shape)
hist_b[:5]

# %%
hist_g = cv2.calcHist([img], channels=[1], mask=None, histSize=[256], ranges=[0,256])
hist_r = cv2.calcHist([img], channels=[2], mask=None, histSize=[256], ranges=[0,256])

import matplotlib.pyplot as plt
plt.plot(hist_r, color="r", label="Red")
plt.plot(hist_g, color="g", label="Green")
plt.plot(hist_b, color="b", label="Blue")
plt.legend()
plt.show()

# %% [markdown]
# ## ノック６５：RGB変換を行って画像を表示してみよう

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_rgb.shape

# %%
#cv2.imshow("img_rgb.jpg", img_rgb)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
display(Image.fromarray(img_rgb))

# %%
plt.imshow(img_rgb)

# %%
plt.imshow(img)

# %% [markdown]
# ## ノック６６：画像のサイズを変更してみよう

# %%
height, width, channels = img.shape
print(width, height)

# %%
img_resized = cv2.resize(img, (500,300))
print(img_resized.shape)
#cv2.imshow("img_resized.jpg", img_resized)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
display(Image.fromarray(img_resized))

# %%
img_resized = cv2.resize(img, (300,500))
print(img_resized.shape)
#cv2.imshow("img_resized.jpg", img_resized)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
display(Image.fromarray(img_resized))

# %%
img_resized = cv2.resize(img, None, fx=0.1, fy=0.1)
print(img_resized.shape)
#cv2.imshow("img_resized.jpg", img_resized)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
display(Image.fromarray(img_resized))

# %%
img_resized_2 = cv2.resize(img, None, fx=1.5, fy=1.5)
print(img_resized_2.shape)
#cv2.imshow("img_resized_2.jpg", img_resized_2)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
display(Image.fromarray(img_resized_2))

# %%
img_resized_2 = cv2.resize(img, None, fx=1.5, fy=1.5, interpolation=cv2.INTER_NEAREST)
print(img_resized_2.shape)
#cv2.imshow("img_resized_2.jpg", img_resized_2)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
display(Image.fromarray(img_resized_2))

# %% [markdown]
# ## ノック６７：画像を回転させてみよう

# %%
#cv2.imshow("img_resized.jpg", img_resized)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
display(Image.fromarray(img_resized))
print(img_resized.shape)

# %%
img_rotated = cv2.rotate(img_resized, cv2.ROTATE_90_CLOCKWISE)
#cv2.imshow("img_rotated.jpg", img_rotated)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
display(Image.fromarray(img_rotated))

print(img_rotated.shape)

# %%
height, width = img_resized.shape[:2]
center = (int(width/2), int(height/2))

rot = cv2.getRotationMatrix2D(center, 45, 1)
img_rotated = cv2.warpAffine(img_resized, rot, (width, height))
#cv2.imshow("img_rotated.jpg", img_rotated)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
display(Image.fromarray(img_rotated))
print(img_rotated.shape)

# %%
img_reverse = cv2.flip(img_resized, 0)
#cv2.imshow("img_reverse.jpg", img_reverse)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
display(Image.fromarray(img_reverse))
print(img_reverse.shape)

# %%
img_reverse = cv2.flip(img_resized, 1)
#cv2.imshow("img_reverse.jpg", img_reverse)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
display(Image.fromarray(img_reverse))
print(img_reverse.shape)

# %%
img_reverse = img_resized[:, ::-1, :]
#cv2.imshow("img_reverse.jpg", img_reverse)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
display(Image.fromarray(img_reverse))
print(img_reverse.shape)

# %% [markdown]
# ## ノック６８：画像処理をしてみよう

# %%
img_gray = cv2.cvtColor(img_resized, cv2.COLOR_BGR2GRAY)
#cv2.imshow("img_gray.jpg", img_gray)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
display(Image.fromarray(img_gray))
print(img_gray.shape)

# %%
th, img_th = cv2.threshold(img_gray, 60, 256, cv2.THRESH_BINARY)
#cv2.imshow("img_th.jpg", img_th)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
display(Image.fromarray(img_th))
print(img_th.shape)

# %%
img_smoothed = cv2.blur(img_resized, (8,8))
#cv2.imshow("img_smoothed.jpg", img_smoothed)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
display(Image.fromarray(img_smoothed))
print(img_smoothed.shape)

# %%
img_smoothed = cv2.blur(img_resized, (20,20))
#cv2.imshow("img_smoothed.jpg", img_smoothed)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
display(Image.fromarray(img_smoothed))
print(img_smoothed.shape)

# %% [markdown]
# ## ノック６９：画像にテキストや線を描画してみよう

# %%
text = '9'
xy = (200, 100)
font = cv2.FONT_HERSHEY_COMPLEX
font_scale = 2
color = (0,0,255)
thickness = 2

img_text = cv2.putText(img_resized.copy(), text, xy, font, font_scale, color, thickness)
#cv2.imshow("img_text.jpg", img_text)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
display(Image.fromarray(img_text))

# %%
x0, y0 = 200, 70
x1, y1 = 350, 330
color = (0,0,255)
thickness = 3

img_rect = cv2.rectangle(img_resized.copy(), (x0,y0), (x1, y1), color, thickness)
#cv2.imshow("img_rect.jpg", img_rect)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
display(Image.fromarray(img_rect))

# %% [markdown]
# ## ノック７０：画像を保存してみよう

# %%
cv2.imwrite("../data/sample_resized.jpg", img_resized)

# %%
img_read = cv2.imread("../data/sample_resized.jpg")
#cv2.imshow("img_read.jpg", img_read)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
display(Image.fromarray(img_read))
